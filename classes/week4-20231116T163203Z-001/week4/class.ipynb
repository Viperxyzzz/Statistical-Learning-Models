# %%
import pandas as pd
import numpy as np

# %%
#read xlsx with the sheet D2SMSA and columns are  the second row
df = pd.read_excel('D2SMSA.xlsx', sheet_name='D2SMSA', header=1)
df.head(5)
# Out:
#    id  land  populat  pcity  psen  nophy  nobed  highschgr  laborf   pinc  \
# 0   1  1384     9387   78.1  12.3  25627  69678       50.1  4083.9  72100
# 1   2  4069     7031   44.0  10.0  15389  39699       62.0  3353.6  52737
# 2   3  3719     7017   43.9   9.4  13326  43292       53.9  3305.9  54542
# 3   4  3553     4794   37.4  10.7   9724  33731       50.6  2066.3  33216
# 4   5  3916     4370   29.9   8.8   6402  24167       52.2  1966.7  32906
#
#     crime  reg  crime/pop
# 0  709234    1  75.554916
# 1  499813    4  71.087043
# 2  393162    2  56.029927
# 3  198102    1  41.322904
# 4  294466    2  67.383524

# %%
df = df[['crime/pop','nophy', 'nobed', 'highschgr', 'laborf', 'pinc']]
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ca03a_row0_col0, #T_ca03a_row1_col1, #T_ca03a_row2_col2, #T_ca03a_row3_col3, #T_ca03a_row4_col4, #T_ca03a_row4_col5, #T_ca03a_row5_col4, #T_ca03a_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ca03a_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ca03a_row0_col2, #T_ca03a_row0_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ca03a_row0_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ca03a_row0_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ca03a_row1_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ca03a_row1_col2, #T_ca03a_row2_col1, #T_ca03a_row2_col5, #T_ca03a_row5_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_ca03a_row1_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ca03a_row1_col4, #T_ca03a_row4_col1, #T_ca03a_row4_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ##### Are variables correlated to the crime/pop
# We should remove nobed
#
# ##### Are variables correlated between themselves?
# If we keep pinc we should remove laborf
#
#
# Results
# Normal - 0.1979
#
# Remove nobed - 0.1713
#
# Remove laborf keep pinc - 0.1953
#
# Remove pinc keep laborf - 0.1976
#
# Remove nobed & laborf keep pinc - 0.1678

# %%
#do a vif analysis to see if there is any multicollinearity between the variables
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

X = add_constant(df[['nophy', 'nobed', 'highschgr', 'laborf', 'pinc']])
pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# const         58.283224
# nophy         33.171839
# nobed         25.652390
# highschgr      1.126379
# laborf       174.532432
# pinc         252.775266
# dtype: float64

# %% [markdown]
# #### only highschgr
